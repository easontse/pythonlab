# %%
import json, csv
import gensim

model = gensim.models.Word2Vec.load_word2vec_format('autohome_word_only.vector',binary=False)
autohome_count = csv.reader(open('autohome_count.csv', 'r'))

target_words = ['U6','车','纳智捷','优6','价格','油耗']

related_words = []
for i in target_words:  
    related_words.append([x for x,_ in model.most_similar(i)[0:5]])

related_words_unpack = []
for i in related_words:
    for x in i:
        related_words_unpack.append(x)

count_dict = {row[0]:int(row[1]) for row in autohome_count if row[0] in related_words_unpack}

with open('autohome_with_adj_n.csv','r') as raw_data:
    csv_reader = csv.reader(raw_data)
    a = []
    for row in csv_reader:
        for word in related_words_unpack:
            if word in row[5] and [word, row[2]] not in a:
                a.append([word, row[2]])

dict_list= {word:[i[1] for i in a if i[0] == word][:5] for word in related_words_unpack}

dataset = []
for i in target_words:
    dataset.append(
        {'name':i,
         'children': [{'topic':x,
                       'rate':count_dict[x], 
                       'link':[
                                {'title':y,'url':'https://www.google.ca/?gws_rd=ssl'} 
                                for y in dict_list[x]
                              ]
                      } for x,_ in model.most_similar(i)[0:5]]
        }
    )

print(json.dumps(dataset, indent=4, ensure_ascii=False))
    
with open('autohome.json','w') as outfile:
    outfile.write(json.dumps(dataset, outfile, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "name": "U6",
#         "children": [
#             {
#                 "topic": "上市",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "『公告』2014年纳智捷U6论坛版规/精华/认证说明"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "GTR粉前来优6论坛报到，希望大家帮我顶上去，被水野大人看到！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "6月6深港澳车展直播双SUV上市，带你目击现场！66666"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "为全国纳智捷车主谋权益，共同见证民族品牌成长历程！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "广州车展看的这几辆，我们宿舍集齐了！"
#                     }
#                 ],
#                 "rate": 3749
#             },
#             {
#                 "topic": "新车",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "『公告』2014年纳智捷U6论坛版规/精华/认证说明"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "不能同年同月同日提优6了，我的智尊要等等等"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "GTR粉前来优6论坛报到，希望大家帮我顶上去，被水野大人看到！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "6月6深港澳车展直播双SUV上市，带你目击现场！66666"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷优6 1.8T超炫登场...."
#                     }
#                 ],
#                 "rate": 1326
#             },
#             {
#                 "topic": "页面",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷好声音争霸赛，战五渣也要来踹一脚热闹！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "“超6”或“优6”亲们 咋看"
#                     }
#                 ],
#                 "rate": 914
#             },
#             {
#                 "topic": "大陆",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "为全国纳智捷车主谋权益，共同见证民族品牌成长历程！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "2015款优6提车记，骚蓝就是漂亮（内附多图，未成年人慎入）"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "可连接手机 体验纳智捷优6 SUV多媒体"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "奇缘妙车*纳智捷U6智尊白2.0T*配高清软妹子倾情奉献"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "烦请我们高尚无比的啊布解释下他自己说的话"
#                     }
#                 ],
#                 "rate": 1127
#             },
#             {
#                 "topic": "命名",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "转载 深刻揭露自主品牌的前世今生"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "鲁K587XX，1.8T时尚星光檀提车作业"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "14.98万？？？别被所谓的新闻忽悠了。"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷跨界SUV六月六日上市 14.98万起"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "“超6”或“优6”亲们 咋看"
#                     }
#                 ],
#                 "rate": 1845
#             }
#         ]
#     },
#     {
#         "name": "车",
#         "children": [
#             {
#                 "topic": "车长",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "初秋清雨桂花香 时尚运动颜值高    -优6 SUV 1.8T 提车/用车"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "老爸居然买了辆优6回来，真是醉了"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "揭穿忽悠人的汽车数据参数"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "让你的爱车最省油"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "一不小心讨到了个小6，长脸了。"
#                     }
#                 ],
#                 "rate": 928
#             },
#             {
#                 "topic": "排气管",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "哪些兄弟的车和我一样有这些问题啊？"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "【哈尔滨】纳智捷u6车友会第一次大聚会（开心开心极了）"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "十一加了六天班，搭个末班车逛公园"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "u6异响、有点苦恼"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "奇缘妙车*纳智捷U6智尊白2.0T*配高清软妹子倾情奉献"
#                     }
#                 ],
#                 "rate": 961
#             },
#             {
#                 "topic": "大气",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "初秋清雨桂花香 时尚运动颜值高    -优6 SUV 1.8T 提车/用车"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "温暖冬季~爱车养护课堂来咯！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "第一次去提优6，我滴那个心情！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "u6时尚升级版！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "优6冬季胎压前后轮多大气压合适…"
#                     }
#                 ],
#                 "rate": 1000
#             },
#             {
#                 "topic": "双方",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "半夜优6驰骋大马路"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "一个司机的自我修养：路怒症出没小心！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "贷款买纳智捷6要啥证件"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "亲们~来拿800元油卡啦！合肥生活馆政策：老带新活动！！！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "买U6--找伙伴--送800油卡"
#                     }
#                 ],
#                 "rate": 928
#             },
#             {
#                 "topic": "形",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "初秋清雨桂花香 时尚运动颜值高    -优6 SUV 1.8T 提车/用车"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "GTR粉前来优6论坛报到，希望大家帮我顶上去，被水野大人看到！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "提小6作业"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷U6 ECO省油神器，杠杠的"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "四川南充：纳智捷U61.8T时尚白《 改宾利电镀中网 》..."
#                     }
#                 ],
#                 "rate": 914
#             }
#         ]
#     },
#     {
#         "name": "纳智捷",
#         "children": [
#             {
#                 "topic": "台湾",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "初秋清雨桂花香 时尚运动颜值高    -优6 SUV 1.8T 提车/用车"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "GTR粉前来优6论坛报到，希望大家帮我顶上去，被水野大人看到！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "6月6深港澳车展直播双SUV上市，带你目击现场！66666"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "我们最爱的帅气小优6，用车感受大家分享。。。。。"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "四川南充：纳智捷U61.8T时尚白《 改宾利电镀中网 》..."
#                     }
#                 ],
#                 "rate": 1401
#             },
#             {
#                 "topic": "方面",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "初秋清雨桂花香 时尚运动颜值高    -优6 SUV 1.8T 提车/用车"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "云想衣裳花想容，漂亮媳妇当车模，媳妇爱车同出镜！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "媳妇坐阵当车模，优6用车作业大片"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "为全国纳智捷车主谋权益，共同见证民族品牌成长历程！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "我们最爱的帅气小优6，用车感受大家分享。。。。。"
#                     }
#                 ],
#                 "rate": 1141
#             },
#             {
#                 "topic": "新车",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "『公告』2014年纳智捷U6论坛版规/精华/认证说明"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "不能同年同月同日提优6了，我的智尊要等等等"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "GTR粉前来优6论坛报到，希望大家帮我顶上去，被水野大人看到！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "6月6深港澳车展直播双SUV上市，带你目击现场！66666"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷优6 1.8T超炫登场...."
#                     }
#                 ],
#                 "rate": 1326
#             },
#             {
#                 "topic": "优胜者",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "“超6”或“优6”亲们 咋看"
#                     }
#                 ],
#                 "rate": 913
#             },
#             {
#                 "topic": "命名",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "转载 深刻揭露自主品牌的前世今生"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "鲁K587XX，1.8T时尚星光檀提车作业"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "14.98万？？？别被所谓的新闻忽悠了。"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷跨界SUV六月六日上市 14.98万起"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "“超6”或“优6”亲们 咋看"
#                     }
#                 ],
#                 "rate": 1845
#             }
#         ]
#     },
#     {
#         "name": "优6",
#         "children": [
#             {
#                 "topic": "潮流",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "上了优6至尊2.0T，pass了3008"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "今天我是来骂人的！！！纳智捷 ，你TM可以厚道点吗！！！！！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "杭州开机  零距离直击新时尚盛宴"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "《超模学院》杭州开机  零距离直击新时尚盛宴"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "关于优6发动机的问题"
#                     }
#                 ],
#                 "rate": 923
#             },
#             {
#                 "topic": "传统",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "GTR粉前来优6论坛报到，希望大家帮我顶上去，被水野大人看到！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "优6 SUV，省油才是王道"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "冬季怎么保护优6的车漆好一点？"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纪念抗战老兵，优6车友在行动"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "风雨归来，给小六子（优6）拍片集赞"
#                     }
#                 ],
#                 "rate": 933
#             },
#             {
#                 "topic": "全面",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "『公告』2014年纳智捷U6论坛版规/精华/认证说明"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "为全国纳智捷车主谋权益，共同见证民族品牌成长历程！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "2.0智尊优6二保现场全程跟踪，与纳智捷技师亲密接触"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "云南大理西游记，苍山、洱海、梯田、夕阳……"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "出发前的“体检”"
#                     }
#                 ],
#                 "rate": 951
#             },
#             {
#                 "topic": "谐音",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "上海纳智捷U6车友会车标图！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "“超6”或“优6”亲们 咋看"
#                     }
#                 ],
#                 "rate": 914
#             },
#             {
#                 "topic": "新",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "『公告』2014年纳智捷U6论坛版规/精华/认证说明"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "初秋清雨桂花香 时尚运动颜值高    -优6 SUV 1.8T 提车/用车"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "云想衣裳花想容，漂亮媳妇当车模，媳妇爱车同出镜！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "不能同年同月同日提优6了，我的智尊要等等等"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "GTR粉前来优6论坛报到，希望大家帮我顶上去，被水野大人看到！"
#                     }
#                 ],
#                 "rate": 940
#             }
#         ]
#     },
#     {
#         "name": "价格",
#         "children": [
#             {
#                 "topic": "台湾地区",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷优六，我的性价比之王"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "为什么我首保机油10w....湾仔们都是5w"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "2015款纳智捷U6台湾4月上市，外观动力配置全面升级，价格不变"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "长春的优粉有福了！！！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "14.98万？？？别被所谓的新闻忽悠了。"
#                     }
#                 ],
#                 "rate": 12
#             },
#             {
#                 "topic": "新车",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "『公告』2014年纳智捷U6论坛版规/精华/认证说明"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "不能同年同月同日提优6了，我的智尊要等等等"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "GTR粉前来优6论坛报到，希望大家帮我顶上去，被水野大人看到！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "6月6深港澳车展直播双SUV上市，带你目击现场！66666"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷优6 1.8T超炫登场...."
#                     }
#                 ],
#                 "rate": 1326
#             },
#             {
#                 "topic": "销量",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "初秋清雨桂花香 时尚运动颜值高    -优6 SUV 1.8T 提车/用车"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "为全国纳智捷车主谋权益，共同见证民族品牌成长历程！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "四川南充：纳智捷U61.8T时尚白《 改宾利电镀中网 》..."
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "全系降价3.5万？这不可能吧！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷太抠了"
#                     }
#                 ],
#                 "rate": 1223
#             },
#             {
#                 "topic": "运城",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "『公告』2014年纳智捷U6论坛版规/精华/认证说明"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "山西运城纳智捷优6交流群：210624453"
#                     }
#                 ],
#                 "rate": 9
#             },
#             {
#                 "topic": "左想",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "在天猫定了车  果断退掉"
#                     }
#                 ],
#                 "rate": 5
#             }
#         ]
#     },
#     {
#         "name": "油耗",
#         "children": [
#             {
#                 "topic": "排量",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "优6用车感想之内饰篇"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "1.6升及以下排量乘用车实施减半征收车辆购置税的优惠政策"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷发动机，"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "官方大降价，购买需谨慎。"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "砖家解答“涡轮增压发动机”的优缺点"
#                     }
#                 ],
#                 "rate": 126
#             },
#             {
#                 "topic": "数据",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "内部消息,纳智捷销量下滑,濒临倒闭....."
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷发动机，"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "破烂的垃圾台湾纳智捷"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "官方大降价，购买需谨慎。"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "这回油耗降下来了吧"
#                     }
#                 ],
#                 "rate": 141
#             },
#             {
#                 "topic": "车重",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷小6，我的正确选择"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "12个油耗百公里-----1.8T普遍反映怎么这么高啊！！！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "2015新款问题。。？放弃"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "让事实说话，用事实印证我之前的油耗帖"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "青海西宁U6提车一周作业（多图申精）"
#                     }
#                 ],
#                 "rate": 18
#             },
#             {
#                 "topic": "市区",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "初秋清雨桂花香 时尚运动颜值高    -优6 SUV 1.8T 提车/用车"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "云想衣裳花想容，漂亮媳妇当车模，媳妇爱车同出镜！"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "生死惊魂   被追尾的自述"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "媳妇坐阵当车模，优6用车作业大片"
#                     },
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "纳智捷优6 1.8T超炫登场...."
#                     }
#                 ],
#                 "rate": 339
#             },
#             {
#                 "topic": "菲翔",
#                 "link": [
#                     {
#                         "url": "https://www.google.ca/?gws_rd=ssl",
#                         "title": "让事实说话，用事实印证我之前的油耗帖"
#                     }
#                 ],
#                 "rate": 24
#             }
#         ]
#     }
# ]

# %%
import json, csv
import gensim

model = gensim.models.Word2Vec.load_word2vec_format('autohome_word_only.vector',binary=False)
autohome_count = csv.reader(open('autohome_count.csv', 'r'))

target_words = ['U6','车','纳智捷','优6','上市','感觉']

related_words = []
for i in target_words:  
    related_words.append([x for x,_ in model.most_similar(i)[0:5]])

related_words_unpack = []
for i in related_words:
    for x in i:
        related_words_unpack.append(x)

count_dict = {row[0]:int(row[1]) for row in autohome_count if row[0] in related_words_unpack}

a = []
for i in target_words:
    a.append(
        {'name':i,
         'children': [{'topic':x, 'rate':count_dict[x]} for x,_ in model.most_similar(i)[0:5]]
        }
    )

print(json.dumps(a, indent=4, ensure_ascii=False))
    
#with open('autohome.json','w') as outfile:
#    json.dumps(a, outfile, indent=4, ensure_ascii=False)
