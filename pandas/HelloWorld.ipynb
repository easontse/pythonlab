# %%
Text1 = 'Hello'

# %%
print Text1
# Out:
# Hello

# %%
Text2 = 'World'

# %%
print Text1+" "+Text2
# Out:
# Hello World

# %%
print (1+12)*15
# Out:
# 195

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X=linspace(0,5)

# %%
plot(X,sin(X))

# %%
from IPython.core.display import Image
Image('http://dsp.im/wp-content/uploads/2014/10/DSP_LOG01.png')

# %%
import pandas as pd
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
broken_df=pd.read_csv('~/ubike-utf8.csv',
                     encoding='utf8')

# %%
broken_df.shape #Check the numbers of row and col
# Out:
# (202014, 16)

# %%
broken_df[:3] #Print top 3 rows
# Out:
#            日期  時間  場站代號 場站區域            場站名稱         經度          緯度  總停車格  \
# 0  2014-12-08  15     2  大安區  捷運國父紀念館站(2號出口)  25.041000  121.556945    48
# 1  2014-12-08  15     3  信義區           台北市政府  25.037797  121.565169    40
# 2  2014-12-08  15     4  信義區            市民廣場  25.036036  121.562325    60
#
#     平均車輛數  最大車輛數  最小車輛數  車輛數標準差   平均空位數  最大空位數  最小空位數  空位數標準差
# 0  24.000     27     23   1.549  22.000     23     19       2
# 1  10.333     13      8   1.862  29.667     32     27       2
# 2  39.333     40     38   1.033  20.667     22     20       1

# %%
broken_df[u'場站名稱'] #Print specific col
# Out:
# 0         捷運國父紀念館站(2號出口)
# 1                  台北市政府
# 2                   市民廣場
# 3                   興雅國中
# 4                   世貿二館
# 5            信義廣場(台北101)
# 6                   世貿三館
# 7                    松德站
# 8              台北市災害應變中心
# 9                    三張犁
# 10                臺北醫學大學
# 11                  福德公園
# 12                  榮星花園
# 13                  饒河夜市
# 14                  松山家商
# 15                民生光復路口
# 16                   社教館
# 17                  中強公園
# 18               捷運科技大樓站
# 19                民生敦化路口
# 20                  松山車站
# 21                  東新國小
# 22                信義建國路口
# 23                永吉松信路口
# 24           捷運昆陽站(1號出口)
# 25        捷運南港展覽館站(5號出口)
# 26                  五常公園
# 27                金山愛國路口
# 28                基隆長興路口
# 29                辛亥新生路口
#                ...
# 201984            中興寶橋路口
# 201985             新莊棒球場
# 201986              頂溪國小
# 201987              永和國小
# 201988              秀朗國小
# 201989            台北慈濟醫院
# ...

# %%
broken_df[:3][u'場站名稱']  #Print top 3 rows in specific col
# Out:
# 0    捷運國父紀念館站(2號出口)
# 1             台北市政府
# 2              市民廣場
# Name: 場站名稱, dtype: object

# %%
broken_df[:100][u'平均車輛數'].plot() #Plot a graph of 平均車輛數, values must be numbers

# %%
broken_df[:100].plot(figsize=(15,5))

# %%
broken_df[:100].plot(subplots=True,figsize=(15,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f09a4bae550>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f099fbcf3d0>], dtype=object)

# %%
import psycopg2

# %%
dbconn_host='localhost'
dbconn_dbname='ubike'
dbconn_user='lab'
dbconn_password='lab'
dbconn_port='5432'

conn_string = ('host=' + "'" + dbconn_host + "'" + ' ' +
              'dbname=' + "'" + dbconn_dbname + "'" + ' ' +
              'user=' + "'" + dbconn_user + "'" + ' ' +
              'password=' + "'" + dbconn_password + "'" + ' ' +
              'port=' + "'" + dbconn_port + "'")

conn = psycopg2.connect(conn_string)
cursor = conn.cursor()
# Out:
# host='localhost' dbname='ubike' user='lab' password='lab' port='5432'
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-30-3099ebe50180> in <module>()
#      11               'port=' + "'" + dbconn_port + "'")
#      12 print conn_string
# ---> 13 conn = psycopg2.connect(conn_string)
#      14 cursor = conn.cursor()
#
# /usr/local/lib/python2.7/dist-packages/psycopg2/__init__.pyc in connect(dsn, database, user, password, host, port, connection_factory, cursor_factory, async, **kwargs)
#     162                 for (k, v) in items])
#     163
# --> 164     conn = _connect(dsn, connection_factory=connection_factory, async=async)
#     165     if cursor_factory is not None:
#     166         conn.cursor_factory = cursor_factory
#
# OperationalError: FATAL:  password authentication failed for user "lab"
# FATAL:  password authentication failed for user "lab"
