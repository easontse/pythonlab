# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number

# Enable inline plotting
# %matplotlib inline

# %pylab inline 
# Must get this or you will get # NameError: name 'figsize' is not defined

import matplotlib.pylab
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
figsize(15, 5) 

print 'Python version ' + sys.version
print 'Pandas version ' + pd.__version__
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Python version 2.7.6 (default, Mar 22 2014, 22:59:56)
# [GCC 4.8.2]
# Pandas version 0.16.0

# %%
import pandas.io.sql
import psycopg2
conn = psycopg2.connect(user='lab')
cur = conn.cursor()

# %%
try:
    cur = conn.cursor()
    cur.execute('SELECT 1')
except psycopg2.OperationalError:
    pass

print conn.closed # if sucessfully connected, conn.close() would be "0"
# Out:
# 0

# %%
# query db
sql = """

select * from ubike limit 3

"""

ubike_df = pandas.io.sql.read_sql(sql, conn)
ubike_df.head()  # try
# Out:
#               when_ts                where_pt code            name area_name  \
# 0 2014-12-08 15:00:00     (25.041,121.556945)    2  捷運國父紀念館站(2號出口)       大安區
# 1 2014-12-08 15:00:00  (25.037797,121.565169)    3           台北市政府       信義區
# 2 2014-12-08 15:00:00  (25.036036,121.562325)    4            市民廣場       信義區
#
#    space_num  avg_bike_num  max_bike_num  min_bike_num  bike_num_std  \
# 0         48        24.000            27            23         1.549
# 1         40        10.333            13             8         1.862
# 2         60        39.333            40            38         1.033
#
#    avg_space_num  max_space_num  min_space_num  space_num_std
# 0         22.000             23             19              2
# 1         29.667             32             27              2
# 2         20.667             22             20              1

# %%
ubike_df.columns
# Out:
# Index([u'when_ts', u'where_pt', u'code', u'name', u'area_name', u'space_num', u'avg_bike_num', u'max_bike_num', u'min_bike_num', u'bike_num_std', u'avg_space_num', u'max_space_num', u'min_space_num', u'space_num_std'], dtype='object')

# %%
ubike_df.dtypes
# Out:
# when_ts          datetime64[ns]
# where_pt                 object
# code                     object
# name                     object
# area_name                object
# space_num                 int64
# avg_bike_num            float64
# max_bike_num              int64
# min_bike_num              int64
# bike_num_std            float64
# avg_space_num           float64
# max_space_num             int64
# min_space_num             int64
# space_num_std           float64
# dtype: object

# %%
# query db
sql = """
select * from ubike 
"""

all = pandas.io.sql.read_sql(sql, conn)

# %%
all['avg_bike_num'] .plot(legend=False)
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1282: UserWarning: findfont: Font family [u'monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# query db
sql = """
select * from ubike where name = '台灣科技大學' and (when_ts  BETWEEN '2014-12-08' AND '2014-12-09')
 order by when_ts; 
"""

df = pandas.io.sql.read_sql(sql, conn)
len(df)
# Out:
# 10

# %%
df
# Out:
#               when_ts              where_pt code    name area_name  space_num  \
# 0 2014-12-08 15:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 1 2014-12-08 16:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 2 2014-12-08 17:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 3 2014-12-08 18:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 4 2014-12-08 19:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 5 2014-12-08 20:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 6 2014-12-08 21:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 7 2014-12-08 22:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 8 2014-12-08 23:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 9 2014-12-09 00:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
#
#    avg_bike_num  max_bike_num  min_bike_num  bike_num_std  avg_space_num  \
# 0        28.000            35            21         5.164         18.000
# 1        11.643            28             1        10.456         34.357
# 2         0.385             1             0         0.506         45.615
# 3         1.600             4             0         1.242         44.400
# 4         3.600             9             0         2.947         42.400
# 5         1.000             4             0         1.254         45.000
# 6         0.200             2             0         0.561         45.800
# 7         0.400             3             0         0.910         45.533
# 8         0.533             3             0         0.915         45.467
# 9         0.286             1             0         0.469         45.714
#
#    max_space_num  min_space_num  space_num_std
# 0             25             11              5
# 1             45             18             10
# 2             46             45              1
# 3             46             42              1
# 4             46             37              3
# 5             46             42              1
# 6             46             44              1
# 7             46             43              1
# 8             46             43              1
# 9             46             45              0

# %%
df[:3]
# Out:
#               when_ts              where_pt code    name area_name  space_num  \
# 0 2014-12-08 15:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 1 2014-12-08 16:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 2 2014-12-08 17:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
#
#    avg_bike_num  max_bike_num  min_bike_num  bike_num_std  avg_space_num  \
# 0        28.000            35            21         5.164         18.000
# 1        11.643            28             1        10.456         34.357
# 2         0.385             1             0         0.506         45.615
#
#    max_space_num  min_space_num  space_num_std
# 0             25             11              5
# 1             45             18             10
# 2             46             45              1

# %%
df[['when_ts','avg_bike_num']]
# Out:
#               when_ts  avg_bike_num
# 0 2014-12-08 15:00:00        28.000
# 1 2014-12-08 16:00:00        11.643
# 2 2014-12-08 17:00:00         0.385
# 3 2014-12-08 18:00:00         1.600
# 4 2014-12-08 19:00:00         3.600
# 5 2014-12-08 20:00:00         1.000
# 6 2014-12-08 21:00:00         0.200
# 7 2014-12-08 22:00:00         0.400
# 8 2014-12-08 23:00:00         0.533
# 9 2014-12-09 00:00:00         0.286

# %%
df[['when_ts','avg_bike_num']].plot()

# %%
# Adjusting Font type settings
from matplotlib.font_manager import FontProperties, findfont

fp = FontProperties(family='monospace', 
                    style='normal',
                    variant='normal',
                    weight='normal',
                    stretch='normal',
                    size='medium')
                  
font = findfont(fp)

# %%
df[['when_ts','avg_bike_num']].plot()

# %%
df[['when_ts','avg_bike_num']].plot(kind='kde')

# %%
# query db
sql = """
select * from ubike where name = '台灣科技大學' and (when_ts  BETWEEN '2014-12-08' AND '2014-12-09')
 order by when_ts; 
"""
df = pandas.io.sql.read_sql(sql, conn)

sql = """
select * from ubike where name = '臺灣師範大學(圖書館)' and (when_ts  BETWEEN '2014-12-08' AND '2014-12-09')
 order by when_ts; 
"""
df2 = pandas.io.sql.read_sql(sql, conn)

# %%
df['avg_bike_num'].plot()
df2['avg_bike_num'].plot()

# %%
df.plot(x='when_ts',y='avg_bike_num')
df2.plot(x='when_ts',y='avg_bike_num')

# %%
df[['max_space_num','min_space_num']].plot(kind='area');

# %%
df[['space_num','max_space_num','min_space_num']].plot(kind='area',stacked=False);

# %%
fig, ax = plt.subplots(1,1)
ax.get_xaxis().set_visible(False)
df[['space_num','max_space_num','min_space_num']].plot(table=True, ax=ax)

# %%
from pandas.tools.plotting import table
fig, ax = plt.subplots(1, 1)
table(ax, np.round(df[['space_num','max_space_num','min_space_num']].describe(), 2),
      loc='lower center', colWidths=[0.1, 0.1, 0.1])
df[['space_num','max_space_num','min_space_num']].plot(table=True, ax=ax)

# try upper left colWidths=[0.1, 0.1, 0.1] table=True   table... remove

# %%
# query db
sql = """


select a.when_ts as time , 
       a.avg_bike_num as point_A, 
       b.avg_bike_num as point_B
from ubike a
inner join ubike b on 
a.when_ts = b.when_ts 
and (a.when_ts  BETWEEN '2014-12-08' AND '2014-12-09') 
and (a.name = '台灣科技大學' and b.name = '臺灣師範大學(圖書館)');


"""

PointJoin = pandas.io.sql.read_sql(sql, conn)
len(PointJoin)
# Out:
# 10

# %%
PointJoin
# Out:
#                  time  point_a  point_b
# 0 2014-12-08 15:00:00   28.000    4.167
# 1 2014-12-08 16:00:00   11.643    1.867
# 2 2014-12-08 17:00:00    0.385    2.154
# 3 2014-12-08 18:00:00    1.600    7.600
# 4 2014-12-08 19:00:00    3.600   17.000
# 5 2014-12-08 20:00:00    1.000    2.933
# 6 2014-12-08 21:00:00    0.200    1.467
# 7 2014-12-08 22:00:00    0.400    1.533
# 8 2014-12-08 23:00:00    0.533    0.733
# 9 2014-12-09 00:00:00    0.286    3.571

# %%
fig, ax = plt.subplots(1, 1)
ax.get_xaxis().set_visible(False)
PointJoin[['point_a','point_b']].plot(table=True, ax=ax)

# %%
df2.plot(kind='bar',x='when_ts', y='avg_bike_num');

# %%
df2[['max_space_num','min_space_num']].plot(kind='bar',alpha=0.6,stacked=True)

# %%
df2[['max_space_num','min_space_num']].plot(kind='barh',alpha=0.6,stacked=True)

# %%
df2[['max_space_num','min_space_num']].plot(kind='hist')

# %%
df2[['max_space_num','min_space_num']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fef4f5b5ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fef4f47e6d0>]], dtype=object)

# %%
# query db
sql = """

select name  from ubike where area_name = '大安區' group by name

"""

pointA = pandas.io.sql.read_sql(sql, conn)
len(pointA)
# Out:
# 30

# %%
pointA
# Out:
#               name
# 0   捷運國父紀念館站(2號出口)
# 1           金山愛國路口
# 2         羅斯福新生南路口
# 3             None
# 4           敦化基隆路口
# 5      臺北市立圖書館(總館)
# 6             龍門廣場
# 7           辛亥新生路口
# 8      臺灣師範大學(圖書館)
# 9             成功國宅
# 10         捷運科技大樓站
# 11     捷運公館站(2號出口)
# 12    捷運忠孝新生(3號出口)
# 13       捷運麟光站2號出口
# 14          建國和平路口
# 15          信義建國路口
# 16          臺大資訊大樓
# 17     捷運東門站(4號出口)
# 18           捷運大安站
# 19            仁愛醫院
# 20       捷運大安森林公園站
# 21          基隆長興路口
# 22          新生和平路口
# 23         捷運信義安和站
# 24          仁愛延吉街口
# 25   捷運台電大樓站(2號出口)
# 26          捷運六張犁站
# 27          台灣科技大學
# 28          信義敦化路口
# 29   捷運忠孝復興站(2號出口)

# %%
# query db
sql = """

select *  from ubike where name  = '台灣科技大學' and (when_ts  BETWEEN '2014-12-01' AND '2014-12-14') order by when_ts

"""

pointA = pandas.io.sql.read_sql(sql, conn)
len(pointA)
# Out:
# 130

# %%
pointA[:2]
# Out:
#               when_ts              where_pt code    name area_name  space_num  \
# 0 2014-12-08 15:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
# 1 2014-12-08 16:00:00  (25.0131,121.539723)   61  台灣科技大學       大安區         46
#
#    avg_bike_num  max_bike_num  min_bike_num  bike_num_std  avg_space_num  \
# 0        28.000            35            21         5.164         18.000
# 1        11.643            28             1        10.456         34.357
#
#    max_space_num  min_space_num  space_num_std
# 0             25             11              5
# 1             45             18             10

# %%
# query db
sql = """

select *  from tpweather where name = '公館國小'  and (when_ts  BETWEEN '2014-12-01' AND '2014-12-14');

"""

weatherA = pandas.io.sql.read_sql(sql, conn)
len(weatherA)
# Out:
# 145

# %%
weatherA[:2]
# Out:
#               when_ts                  where_pt  name     temp  max_temp  \
# 0 2014-12-08 00:00:00  (25.0124078,121.5428079)  公館國小  18.7222      18.7
# 1 2014-12-08 01:00:00  (25.0124078,121.5428079)  公館國小  18.6667      18.7
#
#    min_temp  hum_pct  pressure  wind_speed  rainfall
# 0      18.5       89   1017.24         0.4         0
# 1      18.5       90   1017.20         0.4         0

# %%
# query db
sql = """

select * from tpweather where when_ts in 
    (select when_ts 
      from ubike 
      where name  = '台灣科技大學'  order by when_ts ) 
and name = '公館國小' and (when_ts  BETWEEN '2014-12-01' AND '2014-12-14' ) order by when_ts

"""

weatherA = pandas.io.sql.read_sql(sql, conn)
len(weatherA)
# Out:
# 130

# %%
len(pointA)
# Out:
# 130

# %%
pointA.plot(x='when_ts', y='avg_bike_num')
weatherA.plot(x='when_ts', y='rainfall')

# %%
pointA['avg_bike_num'].plot()
weatherA['rainfall'].plot()

# %%
# query db
sql = """

select distinct on (u.name)
name, code, (select name from tpweather as w order by w.where_pt<->u.where_pt limit 1)
from ubike as u where area_name = '大安區';
"""

calc = pandas.io.sql.read_sql(sql, conn)
calc
# Out:
#               name code  name
# 0           仁愛延吉街口  187  光復國小
# 1             仁愛醫院   63  光復國小
# 2           信義建國路口   24  新生國小
# 3           信義敦化路口   85  光復國小
# 4           台灣科技大學   61  公館國小
# 5           基隆長興路口   30  公館國小
# 6           建國和平路口  181  龍安國小
# 7             成功國宅  128  龍安國小
# 8          捷運信義安和站   71  光復國小
# 9      捷運公館站(2號出口)   45  公館國小
# 10          捷運六張犁站   32  公館國小
# 11   捷運台電大樓站(2號出口)   81  河堤國小
# 12  捷運國父紀念館站(2號出口)    2  光復國小
# 13       捷運大安森林公園站   83  新生國小
# 14           捷運大安站   87  新生國小
# 15   捷運忠孝復興站(2號出口)  111  中正國小
# 16    捷運忠孝新生(3號出口)   47  忠孝國小
# 17     捷運東門站(4號出口)   37  金華國小
# 18         捷運科技大樓站   20  龍安國小
# 19       捷運麟光站2號出口  163  辛亥國小
# 20          敦化基隆路口  126  公館國小
# 21          新生和平路口   57  龍安國小
# 22        羅斯福新生南路口  132  龍安國小
# 23     臺北市立圖書館(總館)   54  新生國小
# 24          臺大資訊大樓   36  龍安國小
# 25     臺灣師範大學(圖書館)   38  新生國小
# 26          辛亥新生路口   31  龍安國小
# 27          金山愛國路口   29  金華國小
# 28            龍門廣場   49  光復國小
# 29            None  185  中正國小
