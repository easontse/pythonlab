# %%
import requests, datetime, time
import pandas as pd
from bs4 import BeautifulSoup

pageNum = 12
url = 'http://forum.u-car.com.tw/index.asp?page=' + str(pageNum) + '&category=19'

index_res = requests.get(url)
index_soup = BeautifulSoup(index_res.text)

def get_linklist(soup):
    link_list = []
    for i in soup.select('a'):

        if 'thread.asp' in i['href']:
            link_list.append('http://forum.u-car.com.tw/' + i['href'])

        counter = 0
        while counter < len(link_list):
            if len(link_list[counter]) == 51:
                link_list[counter] += '&page=1'
            counter += 1
            
    for i in set(link_list):
        if len(i) == 59:
            a = int(i[-2:])

            while a > 4:
                url = i[:57] + str(a)
                if url not in link_list:
                    link_list.append(url)
                a -= 1

        elif len(i) == 60:
            a = int(i[-3:])

            while a > 4:
                url = i[:57] + str(a)
                if url not in link_list:
                    link_list.append(url)
                a -= 1

        elif len(i) == 58 and int(i[-1]) > 4:
            a = int(i[-1:])

            while a > 4:
                url = i[:57] + str(a)
                if url not in link_list:
                    link_list.append(url)
                a -= 1

    return list(set(link_list))

for i in sorted(get_linklist(index_soup)):
    print(i)
# Out:
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=10
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=11
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=12
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=13
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=14
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=15
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=16
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=17
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=18
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=19
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=2
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=20
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=21
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=22
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=23
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=24
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=25
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=26
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=27
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=28
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=29
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=3
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=30
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=31
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=32
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=33
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=34
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=35
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=36
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=37
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=38
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=39
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=4
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=40
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=41
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=42
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=43
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=44
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=45
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=46
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=47
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=48
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=49
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=5
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=50
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=51
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=52
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=53
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=54
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=55
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=56
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=57
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=58
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=59
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=6
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=60
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=7
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=8
# http://forum.u-car.com.tw/thread.asp?forumid=188542&page=9
# http://forum.u-car.com.tw/thread.asp?forumid=250855&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=250855&page=2
# http://forum.u-car.com.tw/thread.asp?forumid=282493&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=282944&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=284998&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=284998&page=2
# http://forum.u-car.com.tw/thread.asp?forumid=285515&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285614&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285685&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285728&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285728&page=2
# http://forum.u-car.com.tw/thread.asp?forumid=285734&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285741&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285781&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285787&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285787&page=2
# http://forum.u-car.com.tw/thread.asp?forumid=285787&page=3
# http://forum.u-car.com.tw/thread.asp?forumid=285787&page=4
# http://forum.u-car.com.tw/thread.asp?forumid=285916&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285933&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285933&page=2
# http://forum.u-car.com.tw/thread.asp?forumid=285951&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285988&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=285994&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=286005&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=286010&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=286015&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=286024&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=286062&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=286112&page=1
# http://forum.u-car.com.tw/thread.asp?forumid=286260&page=1

# %%
import requests, datetime, time, re
import pandas as pd
from bs4 import BeautifulSoup

t1_url = 'http://forum.u-car.com.tw/thread.asp?forumid=285933&page=1'
t1_res = requests.get(t1_url)
t1_soup = BeautifulSoup(t1_res.text)

for i in t1_soup.find_all("div", { "class" : "fd_cont" }):
    print(
        # date
        i.find_all("div", {"class":"memberinfo_top_l"})[0].text[:19],
        # author
        i.find_all("li", {'class':'member_id'})[0].select('a')[0].string,
        # content
        i.find_all('div', {'class':'userwrite'})[0].text
    )
# Out:
# 2015/07/13 11:45:26 firepro å¥½å¨æ²ç­ä»,ä¸ç¶æè²·ä¸èµ·,åªè²·çèµ·Cayenneå¥éæ´æ²¹D5 Momentum+çº324è¬åé«éD5 Inscriptionæ¯349è¬åæ±½æ²¹çT6ç®ååæä¾Inscriptionç­ç´ï¼å®å¹372è¬å
